# %% [markdown]
# ## Data Analysis of Marvel Movies and Lego Sets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
legonewDF = pd.read_csv("/Users/christopherlee/Desktop/Final-Project-On-Lego/legosets.csv")

# %%
# importing csv file on the Lego set releases

# %%
legonewDF
# Out:
#      Item_Number                                             Name  Year  \
# 0          10246                               Detective's Office  2015
# 1          10247                                     Ferris Wheel  2015
# 2          10248                                      Ferrari F40  2015
# 3          10249                                         Toy Shop  2015
# 4          10581                                            Ducks  2015
# 5          10582                                          Animals  2015
# 6          10583                                     Fishing Trip  2015
# 7          10584                                           Forest  2015
# 8          10585                                     Mom and Baby  2015
# 9          10586                                  Ice Cream Truck  2015
# 10         10587                                             Cafe  2015
# 11         10589                                        Rally Car  2015
# 12         10590                                          Airport  2015
# 13         10591                                        Fire Boat  2015
# 14         10592                                       Fire Truck  2015
# 15         10593                                     Fire Station  2015
# 16         10594                     Sofia the First Royal Stable  2015
# 17         10595                     Sofia the First Royal Castle  2015
# 18         10596                       Disney Princess Collection  2015
# 19         10597                  Mickey & Minnie Birthday Parade  2015
# 20         10599                                 Batman Adventure  2015
# 21         10600                                     Classic Race  2015
# 22         10601                                 Delivery Vehicle  2015
# 23         10602                                          Camping  2015
# 24         10603                                     My First Bus  2015
# 25         10604  Jake and the Never Land Pirates Treasure Island  2015
# 26         10605               Doc McStuffins Rosie the Ambulance  2015
# 27         10606                   Doc McStuffins Backyard Clinic  2015
# 28         10607                                     Spider-man 1  2015
# 29         10608                                     Spider-man 2  2015
# ...          ...                                              ...   ...
# 6142         128                        Mobile Crane (Train Base)  1971
# 6143         248                       Factory with Conveyor Belt  1971
# 6144         260                                Dolls Living Room  1971
# 6145         261                                    Dolls Kitchen  1971
# 6146         348                      Garage with Automatic Doors  1971
# 6147         349                                     Swiss Chalet  1971
# 6148         350                                    Spanish Villa  1971
# 6149         351                                     Gravel Depot  1971
# 6150         371                                     Tipper Truck  1971
# 6151         372                                        Tow Truck  1971
# 6152         373                                        Ambulance  1971
# 6153         374                                      Fire Engine  1971
# 6154         375                   Refrigerator Truck and Trailer  1971
# 6155         376                        Low loader with Excavator  1971
# 6156         377                            Crane and Float Truck  1971
# 6157         380                                      Village Set  1971
# 6158         604                                        Excavator  1971
# 6159         605                                             Taxi  1971
# 6160         608                                            Kiosk  1971
# 6161         640                                       Fire Truck  1971
# 6162         642                                 Double Excavator  1971
# 6163         643                                     Mobile Crane  1971
# 6164         644                                    Double Tanker  1971
# 6165         645                          Milk Truck with Trailer  1971
# 6166         646                               Mobile Site Office  1971
# 6167         647                               Lorry With Girders  1971
# 6168         648                                  Service Station  1971
# 6169         795                     2 Large Baseplates, Red/Blue  1971
# 6170         796                 2 Large Baseplates, Green/Yellow  1971
# 6171         798                       2 Medium Baseplates, Green  1971
#
#                 Theme           Subtheme  Pieces  Minifigures  \
# 0     Advanced Models  Modular Buildings  2262.0          6.0
# 1     Advanced Models         Fairground  2464.0         10.0
# 2     Advanced Models           Vehicles  1158.0          NaN
# 3     Advanced Models     Winter Village   898.0          NaN
# 4               Duplo     Forest Animals    13.0          1.0
# 5               Duplo     Forest Animals    39.0          2.0
# 6               Duplo     Forest Animals    32.0          2.0
# 7               Duplo     Forest Animals   105.0          3.0
# 8               Duplo                NaN    13.0          2.0
# 9               Duplo                NaN    11.0          2.0
# 10              Duplo                NaN    52.0          3.0
# 11              Duplo                NaN    13.0          1.0
# 12              Duplo                NaN    29.0          NaN
# 13              Duplo               Fire    19.0          NaN
# 14              Duplo               Fire    26.0          NaN
# 15              Duplo               Fire   105.0          NaN
# 16              Duplo                NaN    38.0          1.0
# 17              Duplo                NaN    87.0          2.0
# 18              Duplo    Disney Princess    63.0          NaN
# 19              Duplo                NaN    24.0          NaN
# 20              Duplo                NaN    47.0          NaN
# 21              Duplo               Cars    29.0          NaN
# 22              Duplo                NaN    19.0          NaN
# 23              Duplo                NaN    38.0          NaN
# 24              Duplo                NaN    17.0          1.0
# 25              Duplo                NaN    25.0          NaN
# 26              Duplo                NaN    16.0          NaN
# 27              Duplo                NaN    39.0          NaN
# 28              Duplo                NaN     NaN          NaN
# 29              Duplo                NaN     NaN          NaN
# ...               ...                ...     ...          ...
# 6142           Trains           4.5/12 V    23.0          NaN
# 6143        Samsonite        Model Maker   248.0          NaN
# 6144        Homemaker                NaN   173.0          NaN
# 6145        Homemaker                NaN   156.0          NaN
# 6146         LEGOLAND           Building    38.0          NaN
# 6147         LEGOLAND               Town    81.0          NaN
# 6148         LEGOLAND           Building   126.0          NaN
# 6149         LEGOLAND                NaN   170.0          NaN
# 6150         LEGOLAND      Large Vehicle    48.0          NaN
# 6151         LEGOLAND      Large Vehicle    54.0          NaN
# 6152         LEGOLAND      Large Vehicle    65.0          NaN
# 6153         LEGOLAND      Large Vehicle    74.0          NaN
# 6154         LEGOLAND      Large Vehicle   128.0          NaN
# 6155         LEGOLAND      Large Vehicle    92.0          NaN
# 6156         LEGOLAND      Large Vehicle    91.0          NaN
# 6157         LEGOLAND           Building   485.0          NaN
# 6158         LEGOLAND            Vehicle    22.0          NaN
# 6159         LEGOLAND            Vehicle    19.0          NaN
# 6160         LEGOLAND                NaN    33.0          NaN
# 6161         LEGOLAND            Vehicle    45.0          NaN
# 6162         LEGOLAND      Large Vehicle    33.0          NaN
# 6163         LEGOLAND            Vehicle    35.0          NaN
# 6164         LEGOLAND                NaN    61.0          NaN
# 6165         LEGOLAND            Vehicle    57.0          NaN
# 6166         LEGOLAND            Vehicle    51.0          NaN
# 6167         LEGOLAND            Vehicle    52.0          NaN
# 6168         LEGOLAND           Building    55.0          NaN
# 6169            Basic    Supplementaries     2.0          NaN
# 6170            Basic    Supplementaries     2.0          NaN
# 6171            Basic    Supplementaries     2.0          NaN
#
#                                               Image_URL  GBP_MSRP  USD_MSRP  \
# 0     http://images.brickset.com/sets/images/10246-1...    132.99  159.9900
# 1     http://images.brickset.com/sets/images/10247-1...    149.99  199.9900
# 2     http://images.brickset.com/sets/images/10248-1...     69.99   99.9900
# 3     http://images.brickset.com/sets/images/10249-1...     59.99   79.9900
# 4     http://images.brickset.com/sets/images/10581-1...      9.99    9.9900
# 5     http://images.brickset.com/sets/images/10582-1...     16.99   19.9900
# 6     http://images.brickset.com/sets/images/10583-1...     19.99   24.9900
# 7     http://images.brickset.com/sets/images/10584-1...     49.99   59.9900
# 8     http://images.brickset.com/sets/images/10585-1...      8.99    9.9900
# 9     http://images.brickset.com/sets/images/10586-1...     12.99   14.9900
# 10    http://images.brickset.com/sets/images/10587-1...     17.99   19.9900
# 11    http://images.brickset.com/sets/images/10589-1...     12.99   14.9900
# 12    http://images.brickset.com/sets/images/10590-1...     16.99   19.9900
# 13    http://images.brickset.com/sets/images/10591-1...     12.99   14.9900
# 14    http://images.brickset.com/sets/images/10592-1...     19.99   24.9900
# 15    http://images.brickset.com/sets/images/10593-1...     44.99   49.9900
# 16    http://images.brickset.com/sets/images/10594-1...     19.99   24.9900
# 17    http://images.brickset.com/sets/images/10595-1...     39.99   49.9900
# 18    http://images.brickset.com/sets/images/10596-1...     34.99   39.9900
# 19    http://images.brickset.com/sets/images/10597-1...     19.99   24.9900
# 20    http://images.brickset.com/sets/images/10599-1...     29.99   39.9900
# 21    http://images.brickset.com/sets/images/10600-1...     20.99   24.9900
# 22    http://images.brickset.com/sets/images/10601-1...     14.99   19.9900
# 23    http://images.brickset.com/sets/images/10602-1...     24.99   29.9900
# 24    http://images.brickset.com/sets/images/10603-1...     12.99   14.9900
# 25    http://images.brickset.com/sets/images/10604-1...     16.99   19.9900
# 26    http://images.brickset.com/sets/images/10605-1...     16.99   19.9900
# 27    http://images.brickset.com/sets/images/10606-1...     19.99   29.9900
# 28    http://images.brickset.com/sets/images/10607-1...       NaN   14.9900
# 29    http://images.brickset.com/sets/images/10608-1...       NaN   29.9900
# ...                                                 ...       ...       ...
# 6142   http://images.brickset.com/sets/images/128-2.jpg      0.88       NaN
# 6143   http://images.brickset.com/sets/images/248-2.jpg       NaN    8.8699
# 6144   http://images.brickset.com/sets/images/260-3.jpg      1.98       NaN
# 6145   http://images.brickset.com/sets/images/261-4.jpg      1.98       NaN
# 6146   http://images.brickset.com/sets/images/348-1.jpg      0.88       NaN
# 6147   http://images.brickset.com/sets/images/349-1.jpg      1.18       NaN
# 6148   http://images.brickset.com/sets/images/350-1.jpg      1.65       NaN
# 6149   http://images.brickset.com/sets/images/351-1.jpg      2.20       NaN
# 6150   http://images.brickset.com/sets/images/371-1.jpg      0.88   14.0000
# 6151   http://images.brickset.com/sets/images/372-2.jpg      0.95       NaN
# 6152   http://images.brickset.com/sets/images/373-2.jpg      1.10       NaN
# 6153   http://images.brickset.com/sets/images/374-2.jpg      1.18       NaN
# 6154   http://images.brickset.com/sets/images/375-3.jpg      1.55       NaN
# 6155   http://images.brickset.com/sets/images/376-1.jpg      1.75       NaN
# 6156   http://images.brickset.com/sets/images/377-2.jpg      1.85       NaN
# 6157   http://images.brickset.com/sets/images/380-1.jpg      5.90       NaN
# 6158   http://images.brickset.com/sets/images/604-2.jpg      0.33       NaN
# 6159   http://images.brickset.com/sets/images/605-2.jpg      0.33       NaN
# 6160   http://images.brickset.com/sets/images/608-1.jpg      0.33       NaN
# 6161   http://images.brickset.com/sets/images/640-1.jpg      0.55       NaN
# 6162   http://images.brickset.com/sets/images/642-2.jpg      0.55       NaN
# 6163   http://images.brickset.com/sets/images/643-2.jpg      0.55       NaN
# 6164   http://images.brickset.com/sets/images/644-1.jpg      0.55       NaN
# 6165   http://images.brickset.com/sets/images/645-2.jpg      0.55       NaN
# 6166   http://images.brickset.com/sets/images/646-2.jpg      0.55       NaN
# 6167   http://images.brickset.com/sets/images/647-1.jpg      0.55       NaN
# 6168   http://images.brickset.com/sets/images/648-1.jpg      0.55       NaN
# 6169   http://images.brickset.com/sets/images/795-1.jpg       NaN    2.1000
# 6170   http://images.brickset.com/sets/images/796-1.jpg       NaN    2.1000
# 6171   http://images.brickset.com/sets/images/798-1.jpg       NaN    3.4000
#
#       CAD_MSRP  EUR_MSRP      Packaging      Availability
# 0       199.99    149.99            Box  Retail - limited
# 1       229.99    179.99            Box  Retail - limited
# 2       119.99     89.99            Box    LEGO exclusive
# 3          NaN     69.99            Box    LEGO exclusive
# 4        12.99      9.99            Box            Retail
# 5        24.99     19.99            Box            Retail
# 6        29.99     24.99            Box            Retail
# 7        69.99     59.99            Box            Retail
# 8        12.99      9.99            Box            Retail
# 9        14.99     14.99            Box            Retail
# 10       24.99     19.99            Box            Retail
# 11       14.99     14.99            Box            Retail
# 12       24.99     19.99            Box            Retail
# 13       14.99     14.99            Box            Retail
# 14       29.99     24.99            Box            Retail
# 15       59.99     59.99            Box            Retail
# 16       29.99     24.99            Box            Retail
# 17       49.99     49.99            Box            Retail
# 18       44.99     39.99            Box            Retail
# 19       29.99     24.99            Box            Retail
# 20       39.99     39.99            Box            Retail
# 21       29.99     24.99            Box            Retail
# 22       19.99     19.99            Box            Retail
# 23       29.99     29.99            Box            Retail
# 24       14.99     14.99            Box            Retail
# 25       19.99     19.99            Box            Retail
# 26       24.99     19.99            Box            Retail
# 27       34.99     34.99            Box            Retail
# 28         NaN       NaN  Not specified     Not specified
# 29         NaN       NaN  Not specified     Not specified
# ...        ...       ...            ...               ...
# 6142       NaN       NaN            Box            Retail
# 6143       NaN       NaN            Box     Not specified
# 6144       NaN       NaN            Box            Retail
# 6145       NaN       NaN            Box            Retail
# 6146       NaN       NaN            Box            Retail
# 6147       NaN       NaN            Box            Retail
# 6148       NaN       NaN            Box            Retail
# 6149       NaN       NaN            Box            Retail
# 6150       NaN       NaN            Box            Retail
# 6151       NaN       NaN            Box            Retail
# 6152       NaN       NaN            Box            Retail
# 6153       NaN       NaN            Box            Retail
# 6154       NaN       NaN            Box            Retail
# 6155       NaN       NaN            Box            Retail
# 6156       NaN       NaN            Box            Retail
# 6157       NaN       NaN            Box            Retail
# 6158       NaN       NaN            Box            Retail
# 6159       NaN       NaN            Box            Retail
# 6160       NaN       NaN            Box            Retail
# 6161       NaN       NaN            Box            Retail
# 6162       NaN       NaN            Box            Retail
# 6163       NaN       NaN            Box            Retail
# 6164       NaN       NaN            Box            Retail
# 6165       NaN       NaN            Box            Retail
# 6166       NaN       NaN            Box            Retail
# 6167       NaN       NaN            Box            Retail
# 6168       NaN       NaN            Box            Retail
# 6169       NaN       NaN  Not specified     Not specified
# 6170       NaN       NaN  Not specified     Not specified
# 6171       NaN       NaN  Not specified     Not specified
#
# [6172 rows x 14 columns]

# %%
simplifiedLegoDF = legonewDF[["Year", "Theme", "Pieces", "USD_MSRP"]]

# %%
simplifiedLegoDF
# Out:
#       Year            Theme  Pieces  USD_MSRP
# 0     2015  Advanced Models  2262.0  159.9900
# 1     2015  Advanced Models  2464.0  199.9900
# 2     2015  Advanced Models  1158.0   99.9900
# 3     2015  Advanced Models   898.0   79.9900
# 4     2015            Duplo    13.0    9.9900
# 5     2015            Duplo    39.0   19.9900
# 6     2015            Duplo    32.0   24.9900
# 7     2015            Duplo   105.0   59.9900
# 8     2015            Duplo    13.0    9.9900
# 9     2015            Duplo    11.0   14.9900
# 10    2015            Duplo    52.0   19.9900
# 11    2015            Duplo    13.0   14.9900
# 12    2015            Duplo    29.0   19.9900
# 13    2015            Duplo    19.0   14.9900
# 14    2015            Duplo    26.0   24.9900
# 15    2015            Duplo   105.0   49.9900
# 16    2015            Duplo    38.0   24.9900
# 17    2015            Duplo    87.0   49.9900
# 18    2015            Duplo    63.0   39.9900
# 19    2015            Duplo    24.0   24.9900
# 20    2015            Duplo    47.0   39.9900
# 21    2015            Duplo    29.0   24.9900
# 22    2015            Duplo    19.0   19.9900
# 23    2015            Duplo    38.0   29.9900
# 24    2015            Duplo    17.0   14.9900
# 25    2015            Duplo    25.0   19.9900
# 26    2015            Duplo    16.0   19.9900
# 27    2015            Duplo    39.0   29.9900
# 28    2015            Duplo     NaN   14.9900
# 29    2015            Duplo     NaN   29.9900
# ...    ...              ...     ...       ...
# 6142  1971           Trains    23.0       NaN
# 6143  1971        Samsonite   248.0    8.8699
# 6144  1971        Homemaker   173.0       NaN
# 6145  1971        Homemaker   156.0       NaN
# 6146  1971         LEGOLAND    38.0       NaN
# 6147  1971         LEGOLAND    81.0       NaN
# 6148  1971         LEGOLAND   126.0       NaN
# 6149  1971         LEGOLAND   170.0       NaN
# 6150  1971         LEGOLAND    48.0   14.0000
# 6151  1971         LEGOLAND    54.0       NaN
# 6152  1971         LEGOLAND    65.0       NaN
# 6153  1971         LEGOLAND    74.0       NaN
# 6154  1971         LEGOLAND   128.0       NaN
# 6155  1971         LEGOLAND    92.0       NaN
# 6156  1971         LEGOLAND    91.0       NaN
# 6157  1971         LEGOLAND   485.0       NaN
# 6158  1971         LEGOLAND    22.0       NaN
# 6159  1971         LEGOLAND    19.0       NaN
# 6160  1971         LEGOLAND    33.0       NaN
# 6161  1971         LEGOLAND    45.0       NaN
# 6162  1971         LEGOLAND    33.0       NaN
# 6163  1971         LEGOLAND    35.0       NaN
# 6164  1971         LEGOLAND    61.0       NaN
# 6165  1971         LEGOLAND    57.0       NaN
# 6166  1971         LEGOLAND    51.0       NaN
# 6167  1971         LEGOLAND    52.0       NaN
# 6168  1971         LEGOLAND    55.0       NaN
# 6169  1971            Basic     2.0    2.1000
# 6170  1971            Basic     2.0    2.1000
# 6171  1971            Basic     2.0    3.4000
#
# [6172 rows x 4 columns]

# %%
simplifiedLegoDF.drop(simplifiedLegoDF[simplifiedLegoDF.Year < 2002].index)
# Out:
#       Year            Theme  Pieces  USD_MSRP
# 0     2015  Advanced Models  2262.0    159.99
# 1     2015  Advanced Models  2464.0    199.99
# 2     2015  Advanced Models  1158.0     99.99
# 3     2015  Advanced Models   898.0     79.99
# 4     2015            Duplo    13.0      9.99
# 5     2015            Duplo    39.0     19.99
# 6     2015            Duplo    32.0     24.99
# 7     2015            Duplo   105.0     59.99
# 8     2015            Duplo    13.0      9.99
# 9     2015            Duplo    11.0     14.99
# 10    2015            Duplo    52.0     19.99
# 11    2015            Duplo    13.0     14.99
# 12    2015            Duplo    29.0     19.99
# 13    2015            Duplo    19.0     14.99
# 14    2015            Duplo    26.0     24.99
# 15    2015            Duplo   105.0     49.99
# 16    2015            Duplo    38.0     24.99
# 17    2015            Duplo    87.0     49.99
# 18    2015            Duplo    63.0     39.99
# 19    2015            Duplo    24.0     24.99
# 20    2015            Duplo    47.0     39.99
# 21    2015            Duplo    29.0     24.99
# 22    2015            Duplo    19.0     19.99
# 23    2015            Duplo    38.0     29.99
# 24    2015            Duplo    17.0     14.99
# 25    2015            Duplo    25.0     19.99
# 26    2015            Duplo    16.0     19.99
# 27    2015            Duplo    39.0     29.99
# 28    2015            Duplo     NaN     14.99
# 29    2015            Duplo     NaN     29.99
# ...    ...              ...     ...       ...
# 4271  2002           Racers   510.0     50.00
# 4272  2002           Racers   284.0    130.00
# 4273  2002         Bionicle    26.0      3.00
# 4274  2002         Bionicle    28.0      3.00
# 4275  2002         Bionicle    28.0      3.00
# 4276  2002         Bionicle    27.0      3.00
# 4277  2002         Bionicle    27.0      3.00
# 4278  2002         Bionicle    26.0      3.00
# 4279  2002         Bionicle   157.0     15.00
# 4280  2002         Bionicle   378.0     35.00
# 4281  2002         Bionicle   636.0     60.00
# 4282  2002         Bionicle     5.0       NaN
# 4283  2002         Bionicle    41.0      8.00
# 4284  2002         Bionicle    41.0      8.00
# 4285  2002         Bionicle    41.0      8.00
# 4286  2002         Bionicle    41.0      8.00
# 4287  2002         Bionicle    41.0      8.00
# 4288  2002         Bionicle    41.0      8.00
# 4289  2002         Bionicle    41.0      8.00
# 4290  2002         Bionicle    37.0      8.00
# 4291  2002         Bionicle    40.0      8.00
# 4292  2002         Bionicle     5.0      2.00
# 4293  2002         Bionicle    44.0      8.00
# 4294  2002         Bionicle    42.0      8.00
# 4295  2002         Bionicle    36.0      8.00
# 4296  2002         Bionicle     5.0      2.00
# 4297  2002        Education   125.0     91.00
# 4298  2002        Education   105.0     97.00
# 4299  2002        Education    57.0     72.00
# 4300  2002        Education   679.0     55.00
#
# [4301 rows x 4 columns]

# %%
numOfLegoMarvelbyYear = []

# %%
for year in range(2002, 2016):
    cutRows = len(simplifiedLegoDF[(simplifiedLegoDF["Year"] == year) & ((simplifiedLegoDF["Theme"] == "Marvel Super Heroes") | (simplifiedLegoDF["Theme"] == "Spider-Man"))])
    numOfLegoMarvelbyYear.append(cutRows)

# %%
# len(numOfLegoMarvelbyYear)
numOfLegoMarvelbyYear
# Out:
# [0, 3, 5, 0, 0, 0, 0, 0, 0, 0, 12, 6, 13, 12]

# %%
#df1 = legonewDF[["Year","Theme"]]

# %%
#df1.loc[df1["Theme"].isin(["Marvel Super Heroes","Spider-Man"])]

# %%
marvelMoviesDF = pd.read_csv("/Users/christopherlee/Desktop/Final-Project-On-Lego/number of marvel movies.csv")

# %%
marvelMoviesDF
# Out:
#     Year  num_of_marvel_movies
# 0   2001                     0
# 1   2002                     1
# 2   2003                     1
# 3   2004                     1
# 4   2005                     0
# 5   2006                     0
# 6   2007                     1
# 7   2008                     2
# 8   2009                     0
# 9   2010                     1
# 10  2011                     2
# 11  2012                     2
# 12  2013                     2
# 13  2014                     3
# 14  2015                     2

# %%
# importing csv file on the Marvel movie releases

# %%
years = np.array([2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])

# %%
plt.plot(range(2002, 2016), numOfLegoMarvelbyYear)

# %%
# plotting the number of marvel lego sets released by year (2002~2016)

# %%
numOfMarvelLegoSetsbyYear = pd.read_csv("/Users/christopherlee/Desktop/Final-Project-On-Lego/numOfLegoMarvelbyYear.csv")

# %%
legoList = list(numOfMarvelLegoSetsbyYear['num_of_lego_sets_of_marvel_by_year'])
type(legoList)
legoList
# Out:
# [0, 3, 5, 0, 0, 0, 0, 0, 0, 0, 12, 6, 13, 12]

# %%
# turning a column in a csv file into a list

# %%
plt.plot(range(2002, 2016), legoList)

# %%
# plotting the number of marvel lego sets released by year (2002~2016), but using the new list

# %%
marvelMoviesDF = marvelMoviesDF.drop(marvelMoviesDF.index[[0]])

# %%
marvelList = list(marvelMoviesDF['num_of_marvel_movies'])
type(marvelList)
marvelList
# Out:
# [1, 1, 1, 0, 0, 1, 2, 0, 1, 2, 2, 2, 3, 2]

# %%
plt.plot(range(2002, 2016), marvelList)

# %%
plt.bar(range(2002, 2016), marvelList)
# Out:
# <BarContainer object of 14 artists>

# %%
plt.bar(range(2002, 2016), legoList)
# Out:
# <BarContainer object of 14 artists>

# %%
plt.bar(range(2002, 2016), marvelList, color = 'red')
plt.bar(range(2002, 2016), legoList, color = 'blue')
# Out:
# <BarContainer object of 14 artists>

# %%
type(marvelList[0])
# Out:
# int

# %%
N = 14
# men_means = (20, 35, 30, 35, 27)
# men_std = (2, 3, 4, 1, 2)

index = np.arange(N)  # the x locations for the groups
width = 0.5       # the width of the bars
# height = 10

fig, ax = plt.subplots()
rects1 = ax.bar(index, marvelList, width, color='r')
plt.figure(figsize = (100, 100))
# women_means = (25, 32, 34, 20, 25)
# women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(index + width, legoList, width, color='b')

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Correlation of Marvel Lego Sets and Marvel Movies')
ax.set_xticks(index, ('2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'))
# ax.set_xticklabels(('2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'))

ax.set_ylim([0,15])

ax.legend((rects1[0], rects2[0]), ('# of Movies', '# of Lego Sets'))

# %%
fig, ax = plt.subplots()
# ax.set_title("Number of Marvel Movies by Year", fontsize = 14, fontweight = "bold")
ax.set_ylabel("Number of Movies", fontsize = 14,)
ax.set_xlabel("Year", fontsize = 14,)

plt.plot(numOfLegoMarvelbyYear)
# plt.plot()
marvelMoviesDF.num_of_marvel_movies.plot(ax = ax)

plt.legend(loc='upper right')
plt.show()

# %%
fig, ax = plt.subplots()
# ax.set_title("Number of Marvel Movies by Year", fontsize = 14, fontweight = "bold")
ax.set_ylabel("Number of Movies", fontsize = 14,)
ax.set_xlabel("Year", fontsize = 14,)

plt.hist(numOfLegoMarvelbyYear)
# plt.plot()
# marvelMoviesDF.num_of_marvel_movies.plot(ax = ax)

# plt.legend(loc='upper right')
plt.show()

# %%
plt.subplot(1, 2, 1)
legoPlot = output2.simplifiedLegoDF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-01710ce9ed38> in <module>
#       1 plt.subplot(1, 2, 1)
# ----> 2 legoPlot = output2.simplifiedLegoDF
#
# NameError: name 'output2' is not defined

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
fig, ax = plt.subplots()

df1.Theme.plot(ax = ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-3663b4078dae> in <module>
#       1 fig, ax = plt.subplots()
#       2
# ----> 3 df1.Theme.plot(ax = ax)
#       4 plt.show()
#
# NameError: name 'df1' is not defined

# %%
fig, ax = plt.subplots()
t = years
ax.plot(t, marvelMoviesDF.num_of_marvel_movies)
# ax.set_title("Number of Marvel Movies by Year", fontsize = 14, fontweight = "bold")
# ax.set_ylabel("Number of Movies", fontsize = 14,)
# ax.set_xlabel("Year", fontsize = 14,)

ax2 = ax.twinx()
# ax2.set_ylabel("Number of Lego Sets", fontsize = 14)
ax2.plot(t, np.array(numOfLegoMarvelbyYear))

# marvelMoviesDF.num_of_marvel_movies.plot(ax = ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8aa1363d8e45> in <module>
#       1 fig, ax = plt.subplots()
#       2 t = years
# ----> 3 ax.plot(t, marvelMoviesDF.num_of_marvel_movies)
#       4 # ax.set_title("Number of Marvel Movies by Year", fontsize = 14, fontweight = "bold")
#       5 # ax.set_ylabel("Number of Movies", fontsize = 14,)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (14,) and (15,)
